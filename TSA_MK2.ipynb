# %%
import matplotlib.pyplot as plt
import numpy as np
from ThermographyToolSet import *

# %%
csv_folder = "/Users/jaworskj/Desktop/Infrared_thermography/Measurment/Abs_plate_no_filter/flux_data"
frames = ReadingDataToStack(csv_folder)
# Out:
# 3D Array shape: (1800, 512, 512)

# %%
frames.shape
# Out:
# (1800, 512, 512)

# %%
plt.figure(figsize=(8,6))
plt.imshow(frames[700],cmap='gray')
plt.grid(False)
plt.colorbar(label='Radiant Flux')
plt.title('Thermograph')
plt.xlabel('Width of the image')
plt.ylabel('Heidgh of the image')
# Out:
# Text(0, 0.5, 'Heidgh of the image')

# %%
phase_data=phasegram(frames)

# %%
plt.figure(figsize=(8,6))
plt.imshow(phase_data[1],cmap='gray')
plt.grid(False)
plt.colorbar(label='Phase [rad]')
plt.title('Phasegram')
plt.xlabel('Width of the image')
plt.ylabel('Heidgh of the image')
# Out:
# Text(0, 0.5, 'Heidgh of the image')

# %%
csv_pipe="/Users/jaworskj/Desktop/Infrared_thermography/Measurment/Pipe_deep_defect/flux_data"
pipe_frames=ReadingDataToStack(csv_pipe)
# Out:
# 3D Array shape: (1800, 512, 512)

# %%
plt.figure(figsize=(8,6))
plt.imshow(pipe_frames[700],cmap='gray')
plt.grid(False)
plt.colorbar(label='Radiant Flux')
plt.title('Thermograph')
plt.xlabel('Width of the image')
plt.ylabel('Heidgh of the image')
# Out:
# Text(0, 0.5, 'Heidgh of the image')

# %%
pipe_phase=phasegram(pipe_frames)

# %%
plt.figure(figsize=(8,6))
plt.imshow(pipe_phase[1],cmap='gray')
plt.grid(False)
plt.colorbar(label='Phase [rad]')
plt.title('Phasegram')
plt.xlabel('Width of the image')
plt.ylabel('Heidgh of the image')
# Out:
# Text(0, 0.5, 'Heidgh of the image')

# %%
PCT_data=PCT(frames,3)

# %%
plt.figure(figsize=(8,6))
plt.imshow(PCT_data[0],cmap='gray')
plt.grid(False)
plt.colorbar(label='PCA')
plt.title('Principal Component Thermography')
plt.xlabel('Width of the image')
plt.ylabel('Heidgh of the image')
# Out:
# Text(0, 0.5, 'Heidgh of the image')

# %%
pipe_PCT=PCT(pipe_frames,5)

# %%
plt.figure(figsize=(8,6))
plt.imshow(pipe_PCT[0],cmap='gray')
plt.grid(False)
plt.colorbar(label='PCA')
plt.title('Principal Component Thermography')
plt.xlabel('Width of the image')
plt.ylabel('Heidgh of the image')
# Out:
# Text(0, 0.5, 'Heidgh of the image')

# %%
csv_pipe = "/Users/jaworskj/Desktop/Infrared_thermography/Measurment/Pipe_mid_defect/flux_data"
pipe_mid_defect = ReadingDataToStack(csv_pipe)
# Out:
# 3D Array shape: (1800, 512, 512)

# %%
plt.figure(figsize=(8,6))
plt.imshow(pipe_mid_defect[600],cmap='gray')
plt.grid(False)
plt.colorbar(label='Radiant Flux')
plt.title('Thermograph mid defect')
plt.xlabel('Width of the image')
plt.ylabel('Heidgh of the image')
# Out:
# Text(0, 0.5, 'Heidgh of the image')

# %%
pipe_mid_PCT=PCT(pipe_mid_defect,10)

# %%
plt.figure(figsize=(8,6))
plt.imshow(pipe_mid_PCT[3],cmap='gray')
plt.grid(False)
plt.colorbar(label='PCA')
plt.title('Principal Component Thermography mid defect')
plt.xlabel('Width of the image')
plt.ylabel('Heidgh of the image')
# Out:
# Text(0, 0.5, 'Heidgh of the image')

# %%
pipe_mid_defect=phasegram(pipe_mid_defect)

# %%
plt.figure(figsize=(8,6))
plt.imshow(pipe_mid_defect[1],cmap='gray')
plt.grid(False)
plt.colorbar(label='Phase [rad]')
plt.title('Phasegram of mid defect in a pipe')
plt.xlabel('Width of the image')
plt.ylabel('Heidgh of the image')
# Out:
# Text(0, 0.5, 'Heidgh of the image')

# %%
csv_abs_pipe = "/Users/jaworskj/Desktop/Infrared_thermography/Measurment/Circular_ABS/flux_data"
abs_circular_defect = ReadingDataToStack(csv_abs_pipe)
# Out:
# 3D Array shape: (1800, 512, 512)

# %%
abs_circular_PCT=PCT(abs_circular_defect,5)

# %%
plt.figure(figsize=(8,6))
plt.imshow(abs_circular_PCT[4],cmap='gray')
plt.grid(False)
plt.colorbar(label='Phase [rad]')
plt.title('PCT of Circular ABS Sample')
plt.xlabel('Width of the image')
plt.ylabel('Heidgh of the image')
# Out:
# Text(0, 0.5, 'Heidgh of the image')

# %%
abs_circular_phase=phasegram(abs_circular_defect)

# %%
plt.figure(figsize=(8,6))
plt.imshow(abs_circular_phase[1],cmap='gray')
plt.grid(False)
plt.colorbar(label='Phase [rad]')
plt.title('Phasegram of Circular ABS Sample')
plt.xlabel('Width of the image')
plt.ylabel('Heidgh of the image')
# Out:
# Text(0, 0.5, 'Heidgh of the image')
